# %%
import pandas as pd

# %%
post = pd.read_csv("datasets/post_17plus8_X.csv")
n_post = pd.read_csv("datasets/17+8-NovDes-Datasets.csv")

new_post = pd.concat([post, n_post], ignore_index=True)

print('duplicated:', new_post.duplicated().sum())
print(new_post.info())
# Out:
# duplicated: 34
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      837 non-null    int64
#  1   created_at               837 non-null    object
#  2   favorite_count           837 non-null    int64
#  3   full_text                837 non-null    object
#  4   id_str                   837 non-null    int64
#  5   image_url                228 non-null    object
#  6   in_reply_to_screen_name  257 non-null    object
#  7   lang                     837 non-null    object
#  8   location                 0 non-null      float64
#  9   quote_count              837 non-null    int64
#  10  reply_count              837 non-null    int64
#  11  retweet_count            837 non-null    int64
#  12  tweet_url                837 non-null    object
#  13  user_id_str              837 non-null    int64
# ...

# %%
# save the merged
new_post.to_csv("datasets/17plus8.csv", index=False)
new_post
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1965720978492952986  Wed Sep 10 10:16:17 +0000 2025              20
# 1    1966145518167535945  Thu Sep 11 14:23:15 +0000 2025              14
# 2    1965759375513162019  Wed Sep 10 12:48:51 +0000 2025               0
# 3    1967037974971109397  Sun Sep 14 01:29:33 +0000 2025            2343
# 4    1965608459145281989  Wed Sep 10 02:49:10 +0000 2025             103
# ..                   ...                             ...             ...
# 832  1981705085756600602  Fri Oct 24 12:51:25 +0000 2025               2
# 833  1980458439357919527  Tue Oct 21 02:17:41 +0000 2025               0
# 834  1980625768049951162  Wed Oct 22 10:23:42 +0000 2025               0
# 835  1981390869363380720  Thu Oct 23 16:02:50 +0000 2025               0
# 836  1980933135190868235  Wed Oct 22 09:43:58 +0000 2025               0
#
#                                              full_text               id_str  \
# ...
